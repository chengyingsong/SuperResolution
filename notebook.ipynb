# %%
import glob
import os.path as osp
data_folder = r"D:\study\项目\超分\BSDS300\images"
subset = "train"
path = osp.join(data_folder+"\\"+subset,"*.jpg")
print(path)
img_path = glob.glob(path)
print(img_path)
print(len(img_path))
# Out:
# D:\study\项目\超分\BSDS300\images\train\*.jpg
# ...

# %%
path = "D:\study\项目\超分\checkpoint"
f =
